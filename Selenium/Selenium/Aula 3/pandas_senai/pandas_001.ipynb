# %%
import pandas as pd

# %%
df = pd.read_csv('meu_arquivo.csv', encoding='Latin1', sep=';')

# %%
df
# Out:
#     Nome  Idade       Sexo
# 0   João     21  Masculino
# 1  Maria     18   Feminino
# 2  Pedro     34  Masculino
# 3  Joana     25   Feminino

# %%
df.head()
# Out:
#     Nome  Idade       Sexo
# 0   João     21  Masculino
# 1  Maria     18   Feminino
# 2  Pedro     34  Masculino
# 3  Joana     25   Feminino

# %%
df.head(2)
# Out:
#     Nome  Idade       Sexo
# 0   João     21  Masculino
# 1  Maria     18   Feminino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nome    4 non-null      object
#  1   Idade   4 non-null      int64
#  2   Sexo    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (4, 3)

# %%
print(f'O DataFrame contém {df.shape[0]} linhas e {df.shape[1]} colunas ')
# Out:
# O DataFrame contém 4 linhas e 3 colunas

# %% [markdown]
# _____________________________________________________________________________________________

# %%
personagens_df = pd.DataFrame({
    'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade': [13,1000,70],
    'peso': [70.5,  15.2, 60.5],
    'É jedi': [True, True, False]

})

# %%
personagens_df
# Out:
#              nome  idade  peso  É jedi
# 0  Luke Skywalker     13  70.5    True
# 1            Yoda   1000  15.2    True
# 2       Palpatine     70  60.5   False

# %%
personagens_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nome    3 non-null      object
#  1   idade   3 non-null      int64
#  2   peso    3 non-null      float64
#  3   É jedi  3 non-null      bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 203.0+ bytes

# %%
personagens_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'É jedi'], dtype='object')

# %%
from sqlalchemy.sql.expression import column
personagens_df_renomeado = personagens_df.rename(columns={
    'nome': 'Nome Completo',
    'idade': 'Idade Aproximada'
})

# %%
personagens_df_renomeado
# Out:
#     Nome Completo  Idade Aproximada  peso  É jedi
# 0  Luke Skywalker                13  70.5    True
# 1            Yoda              1000  15.2    True
# 2       Palpatine                70  60.5   False

# %%
personagens_df
# Out:
#              nome  idade  peso  É jedi
# 0  Luke Skywalker     13  70.5    True
# 1            Yoda   1000  15.2    True
# 2       Palpatine     70  60.5   False

# %%
personagens_df.columns = ['NOME', 'IDADE', 'PESO', 'É Jedi']

# %%
personagens_df
# Out:
#              NOME  IDADE  PESO  É Jedi
# 0  Luke Skywalker     13  70.5    True
# 1            Yoda   1000  15.2    True
# 2       Palpatine     70  60.5   False

# %%
data = pd.read_csv('GasPricesinBrazil_2004-2019.csv', sep = ';')

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'DATA INICIAL', 'DATA FINAL', 'REGIÃO', 'ESTADO',
#        'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'UNIDADE DE MEDIDA',
#        'PREÇO MÉDIO REVENDA', 'DESVIO PADRÃO REVENDA', 'PREÇO MÍNIMO REVENDA',
#        'PREÇO MÁXIMO REVENDA', 'MARGEM MÉDIA REVENDA',
#        'COEF DE VARIAÇÃO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO',
#        'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO',
#        'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO', 'MÊS',
#        'ANO'],
#       dtype='object')

# %%
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %% [markdown]
# Posição dos estados de acordo com length.

# %%
data.iloc[400]
# Out:
# Unnamed: 0                                    400
# DATA INICIAL                           2004-08-15
# DATA FINAL                             2004-08-21
# REGIÃO                                    SUDESTE
# ESTADO                             RIO DE JANEIRO
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  969
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.359
# DESVIO PADRÃO REVENDA                       0.145
# PREÇO MÍNIMO REVENDA                        1.029
# PREÇO MÁXIMO REVENDA                        1.799
# MARGEM MÉDIA REVENDA                        0.205
# COEF DE VARIAÇÃO REVENDA                    0.107
# PREÇO MÉDIO DISTRIBUIÇÃO                    1.154
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.174
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5444
# PREÇO MÁXIMO DISTRIBUIÇÃO                  1.4976
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.151
# ...
